# %%
import os, sys
currentdir = os.path.dirname(os.path.realpath("Sequence-Analysis.py"))
parentdir = os.path.dirname(currentdir)
sys.path.append(parentdir)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from modules.geophysics import geophysics, seismics
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-90-515791d38c3c> in <module>
#       8 import matplotlib.pyplot as plt
#       9 import matplotlib.patches as mpatches
# ---> 10 from modules.geophysics import geophysics, seismics
#
# ~/gebpy/modules/geophysics.py in <module>
#      15 from numpy import round
#      16 from random import *
# ---> 17 from modules import minerals
#      18 from modules.elements import elements
#      19 from scipy import signal
#
# ~/gebpy/modules/minerals.py in <module>
#      18 import scipy.constants
#      19 from scipy import stats
# ---> 20 from modules.geophysics import BoreholeGeophysics as bg
#      21
#      22 u = scipy.constants.physical_constants["atomic mass constant"]
#
# ImportError: cannot import name 'BoreholeGeophysics' from 'modules.geophysics' (/home/mabubuntu/gebpy/modules/geophysics.py)

# %%
data = "../outputs/SequenceStratigraphy.csv"

# %%
#df = pd.read_csv(data, sep=',', header=0, na_values='.', skiprows=range(1, 3))
df = pd.read_csv(data, sep=',', header=0, na_values='.')

# %%
df
# Out:
#           ROCK  THICKNESS     TOP  BOTTOM   RHOB       VP       VS    GR  \
# 0     dry sand       35.0     0.0    35.0  2.045  4356.30  2567.50  13.8
# 1     wet sand       17.0    35.0    52.0  2.055  4501.13  2637.48  31.5
# 2    sandstone        2.4    52.0    54.4  2.356  4414.93  2811.18   2.6
# 3    sandstone        2.4    54.4    56.9  2.306  4599.83  2703.82  26.4
# 4    sandstone        2.4    56.9    59.4  2.335  4449.70  2809.87   4.5
# ..         ...        ...     ...     ...    ...      ...      ...   ...
# 777    granite        2.2  1504.2  1506.4  2.652  7427.29  4612.66  40.1
# 778    granite        2.2  1506.4  1508.5  2.664  7318.13  4558.78  70.4
# 779    granite        2.2  1508.5  1510.7  2.718  7309.50  4549.72  47.6
# 780    granite        2.2  1510.7  1512.8  2.628  7303.63  4558.22  86.2
# 781    granite        2.2  1512.8  1515.0  2.675  7398.20  4593.80  50.4
#
#      PHIN  FLUID  POISSON    PE
# 0    37.0  water     0.23  2.24
# 1    36.0  water     0.24  2.32
# 2    28.0  water     0.01  1.90
# 3    31.0  water     0.11  2.70
# 4    29.0  water     0.02  2.00
# ..    ...    ...      ...   ...
# 777   2.0  water     0.18  2.40
# 778   1.0  water     0.17  2.60
# 779   1.0  water     0.17  3.10
# 780   2.0  water     0.17  2.60
# 781   1.0  water     0.18  2.50
#
# [782 rows x 12 columns]

# %%
df.describe()
# Out:
#         THICKNESS          TOP       BOTTOM        RHOB           VP  \
# count  782.000000   782.000000   782.000000  782.000000   782.000000
# mean     1.938619   800.843350   802.780051    2.520462  4828.858350
# std      1.573571   435.378624   435.182685    0.495625  1409.103634
# min      0.800000     0.000000    35.000000    1.898000  1908.810000
# 25%      1.300000   403.125000   406.050000    2.228000  4408.915000
# 50%      1.800000   853.700000   855.550000    2.363000  4833.970000
# 75%      2.300000  1187.800000  1189.325000    2.696000  5240.497500
# max     35.000000  1512.800000  1515.000000    4.625000  7573.190000
#
#                 VS          GR        PHIN     POISSON          PE
# count   782.000000  782.000000  782.000000  782.000000  782.000000
# mean   2737.514220   21.423402   20.407928    0.193261    3.972072
# std     888.639703   33.983690   12.541908    0.105508    3.086439
# min    1054.280000    0.000000    0.000000    0.000000    1.800000
# 25%    2338.562500    1.200000    5.000000    0.110000    2.400000
# 50%    2695.530000    5.000000   25.000000    0.225000    3.000000
# 75%    2968.320000   29.850000   30.000000    0.290000    4.900000
# max    4711.930000  196.700000   37.000000    0.330000   22.800000

# %%
depth = []
for
# Out:
#   File "<ipython-input-95-8bb72dff30c5>", line 2
#     for
#         ^
# SyntaxError: invalid syntax

# %%
fig, axs = plt.subplots(3, 2, figsize=(15,20))
inputs = ["RHOB", "VP", "VS", "GR", "PHIN", "POISSON"]
color = "#1f77b4"
edgecolor = "black"
for i in range(0, 3):
    for j in range(0, 2):
        for k in range(0, len(inputs)):
            axs[i,j].set_facecolor("whitesmoke")
            axs[i,j].grid(color="black", linestyle='dashed')
            axs[i,j].set_ylabel("Frequency")
            axs[i,j].set_axisbelow(True)
axs[0,0].hist(df[inputs[0]], bins=25, color=color, edgecolor=edgecolor)
axs[0,0].set_xlabel("RHOB (g/cm$^3$)")
axs[0,1].hist(df[inputs[3]], bins=25, color=color, edgecolor=edgecolor)
axs[0,1].set_xlabel("GR (API)")
axs[1,0].hist(df[inputs[1]], bins=25, color=color, edgecolor=edgecolor)
axs[1,0].set_xlabel("VP (m/s)")
axs[1,1].hist(df[inputs[2]], bins=25, color=color, edgecolor=edgecolor)
axs[1,1].set_xlabel("VS (m/s)")
axs[2,0].hist(df[inputs[4]], bins=25, color=color, edgecolor=edgecolor)
axs[2,0].set_xlabel("PHIN (%)")
axs[2,1].hist(df[inputs[5]], bins=25, color=color, edgecolor=edgecolor)
axs[2,1].set_xlabel("POISSON (1)")
#
#plt.savefig("Histogram-Plot", dpi=600, transparent=False)#

# %%
from pandas.plotting import scatter_matrix
import seaborn as sn

# %%
scatter_matrix(df[["RHOB", "GR", "PHIN", "VP", "VS", "POISSON"]], figsize=(12, 12), diagonal='hist');

# %%
df.corr()
# Out:
#            THICKNESS       TOP    BOTTOM      RHOB        VP        VS  \
# THICKNESS   1.000000 -0.126129 -0.122569 -0.075509 -0.005944 -0.023271
# TOP        -0.126129  1.000000  0.999994 -0.060117  0.574838  0.539157
# BOTTOM     -0.122569  0.999994  1.000000 -0.060430  0.575076  0.539313
# RHOB       -0.075509 -0.060117 -0.060430  1.000000 -0.080942 -0.068492
# VP         -0.005944  0.574838  0.575076 -0.080942  1.000000  0.946031
# VS         -0.023271  0.539157  0.539313 -0.068492  0.946031  1.000000
# GR          0.005565  0.090176  0.090227 -0.119645 -0.149200 -0.038728
# PHIN       -0.041231 -0.244249 -0.244486 -0.531091 -0.093777 -0.195045
# POISSON     0.083149  0.153444  0.153814  0.230293  0.053401 -0.225371
# PE          0.015175 -0.212615 -0.212667  0.748810 -0.333475 -0.414128
#
#                  GR      PHIN   POISSON        PE
# THICKNESS  0.005565 -0.041231  0.083149  0.015175
# TOP        0.090176 -0.244249  0.153444 -0.212615
# BOTTOM     0.090227 -0.244486  0.153814 -0.212667
# RHOB      -0.119645 -0.531091  0.230293  0.748810
# VP        -0.149200 -0.093777  0.053401 -0.333475
# VS        -0.038728 -0.195045 -0.225371 -0.414128
# GR         1.000000 -0.538318  0.012005 -0.169234
# PHIN      -0.538318  1.000000 -0.153541 -0.297773
# POISSON    0.012005 -0.153541  1.000000  0.467661
# PE        -0.169234 -0.297773  0.467661  1.000000

# %%
new_df = df.iloc[:,4:]
new_df.corr()
# Out:
#              RHOB        VP        VS        GR      PHIN   POISSON        PE
# RHOB     1.000000 -0.080942 -0.068492 -0.119645 -0.531091  0.230293  0.748810
# VP      -0.080942  1.000000  0.946031 -0.149200 -0.093777  0.053401 -0.333475
# VS      -0.068492  0.946031  1.000000 -0.038728 -0.195045 -0.225371 -0.414128
# GR      -0.119645 -0.149200 -0.038728  1.000000 -0.538318  0.012005 -0.169234
# PHIN    -0.531091 -0.093777 -0.195045 -0.538318  1.000000 -0.153541 -0.297773
# POISSON  0.230293  0.053401 -0.225371  0.012005 -0.153541  1.000000  0.467661
# PE       0.748810 -0.333475 -0.414128 -0.169234 -0.297773  0.467661  1.000000

# %%
plt.figure(figsize=(12,10))
sn.heatmap(new_df.corr(), cmap="viridis", annot=True);
#plt.savefig("Correlation-Plot", dpi=600, transparent=False)

# %%
fig, axs = plt.subplots(3, 2, figsize=(15,20))
inputs = ["RHOB", "VP", "VS", "GR", "PHIN", "POISSON"]
color = "#1f77b4"
edgecolor = "black"
for i in range(0, 3):
    for j in range(0, 2):
        for k in range(0, len(inputs)):
            axs[i,j].set_facecolor("whitesmoke")
            axs[i,j].grid(color="black", linestyle='dashed')
            axs[i,j].set_xlabel("RHOB (g/cm$^3$)")
            axs[i,j].set_axisbelow(True)
axs[0,0].scatter(df[inputs[0]], df[inputs[1]], color=color, edgecolor=edgecolor)
axs[0,0].set_ylabel("VP (m/s)")
axs[0,1].scatter(df[inputs[0]], df[inputs[2]], color=color, edgecolor=edgecolor)
axs[0,1].set_ylabel("VS (m/s)")
axs[1,0].scatter(df[inputs[0]], df[inputs[3]], color=color, edgecolor=edgecolor)
axs[1,0].set_ylabel("GR (API)")
axs[1,1].scatter(df[inputs[0]], df[inputs[4]], color=color, edgecolor=edgecolor)
axs[1,1].set_ylabel("PHIN (%)")
axs[2,0].scatter(df[inputs[0]], df[inputs[5]], color=color, edgecolor=edgecolor)
axs[2,0].set_ylabel("POISSON (1)")
axs[2,1].scatter(df[inputs[0]], df[inputs[1]]/df[inputs[2]], color=color, edgecolor=edgecolor)
axs[2,1].set_ylabel("VP/VS (1)")
#
# Out:
# Text(0, 0.5, 'VP/VS (1)')

# %%
fig, axs = plt.subplots(3, 2, figsize=(15,20))
for i in range(0, 3):
    for j in range(0, 2):
        for k in range(0, len(inputs)):
            axs[i,j].set_facecolor("whitesmoke")
            axs[i,j].grid(color="black", linestyle='dashed')
            axs[i,j].set_xlabel("RHOB (g/cm$^3$)")
            axs[i,j].set_axisbelow(True)
axs[0,0].scatter(df[inputs[0]], df[inputs[1]], c=df[inputs[3]], cmap="viridis")
axs[0,0].set_ylabel("VP (m/s)")
axs[0,1].scatter(df[inputs[0]], df[inputs[2]], c=df[inputs[3]], cmap="viridis")
axs[0,1].set_ylabel("VS (m/s)")
axs[1,0].scatter(df[inputs[0]], df[inputs[3]], c=df[inputs[3]], cmap="viridis")
axs[1,0].set_ylabel("GR (API)")
axs[1,1].scatter(df[inputs[0]], df[inputs[4]], c=df[inputs[3]], cmap="viridis")
axs[1,1].set_ylabel("PHIN (%)")
axs[2,0].scatter(df[inputs[0]], df[inputs[5]], c=df[inputs[3]], cmap="viridis")
axs[2,0].set_ylabel("POISSON (1)")
axs[2,1].scatter(df[inputs[0]], df[inputs[1]]/df[inputs[2]], c=df[inputs[3]], cmap="viridis")
axs[2,1].set_ylabel("VP/VS (1)")
# Out:
# Text(0, 0.5, 'VP/VS (1)')

# %%
sequenceLog = []
for i in range(0, len(df["ROCK"])):
    sequenceLog.append(df["ROCK"][i])

# %%
plt.figure(figsize=(10,8))
x = df["RHOB"]
y = df["VP"]
coordDrySand = [[],[]]
coordWetSand = [[],[]]
coordScree = [[],[]]
coordSoil = [[],[]]
coordSandstone = [[],[]]
coordLimestone = [[],[]]
coordDolomite = [[],[]]
coordShale = [[],[]]
coordHalite = [[],[]]
coordAnhydrite = [[],[]]
coordGranite = [[],[]]
coordBasalt = [[],[]]
for i in range(0, len(sequenceLog)):
	if sequenceLog[i] == "water":
		continue
	elif sequenceLog[i] == "dry sand":
		coordDrySand[0].append(x[i])
		coordDrySand[1].append(y[i])
	elif sequenceLog[i] == "wet sand":
		coordWetSand[0].append(x[i])
		coordWetSand[1].append(y[i])
	elif sequenceLog[i] == "scree":
		coordScree[0].append(x[i])
		coordScree[1].append(y[i])
	elif sequenceLog[i] == "soil":
		coordSoil[0].append(x[i])
		coordSoil[1].append(y[i])
	elif sequenceLog[i] == "sandstone":
		coordSandstone[0].append(x[i])
		coordSandstone[1].append(y[i])
	elif sequenceLog[i] == "limestone":
		coordLimestone[0].append(x[i])
		coordLimestone[1].append(y[i])
	elif sequenceLog[i] == "dolomite":
		coordDolomite[0].append(x[i])
		coordDolomite[1].append(y[i])
	elif sequenceLog[i] == "shale":
		coordShale[0].append(x[i])
		coordShale[1].append(y[i])
	elif sequenceLog[i] == "halite":
		coordHalite[0].append(x[i])
		coordHalite[1].append(y[i])
	elif sequenceLog[i] == "anhydrite":
		coordAnhydrite[0].append(x[i])
		coordAnhydrite[1].append(y[i])
	elif sequenceLog[i] == "granite":
		coordGranite[0].append(x[i])
		coordGranite[1].append(y[i])
	elif sequenceLog[i] == "basalt":
		coordBasalt[0].append(x[i])
		coordBasalt[1].append(y[i])
if len(coordDrySand[0]) > 0:
	plt.scatter(coordDrySand[0], coordDrySand[1], c="gold", label="dry sand", alpha=0.8)
else:
	pass
if len(coordSoil[0]) > 0:
	plt.scatter(coordSoil[0], coordSoil[1], c="saddlebrown", label="soil", alpha=0.8)
else:
	pass
plt.scatter(coordWetSand[0], coordWetSand[1], c="palegoldenrod", label="wet sand", alpha=0.8)
if len(coordSandstone[0]) > 0:
	plt.scatter(coordSandstone[0], coordSandstone[1], c="peru", label="sandstone", alpha=0.8)
if len(coordLimestone[0]) > 0:
	plt.scatter(coordLimestone[0], coordLimestone[1], c="steelblue", label="limestone", alpha=0.8)
if len(coordDolomite[0]) > 0:
	plt.scatter(coordDolomite[0], coordDolomite[1], c="darkviolet", label="dolomite", alpha=0.8)
if len(coordShale[0]) > 0:
	plt.scatter(coordShale[0], coordShale[1], c="limegreen", label="shale", alpha=0.8)
if len(coordHalite[0]) > 0:
	plt.scatter(coordHalite[0], coordHalite[1], c="thistle", label="halite", alpha=0.8)
if len(coordAnhydrite[0]) > 0:
	plt.scatter(coordAnhydrite[0], coordAnhydrite[1], c="pink", label="anhydrite", alpha=0.8)
if len(coordGranite[0]) > 0:
	plt.scatter(coordGranite[0], coordGranite[1], c="coral", label="granite", alpha=0.8)
if len(coordBasalt[0]) > 0:
	plt.scatter(coordBasalt[0], coordBasalt[1], c="silver", label="basalt", alpha=0.8)
plt.legend(scatterpoints=1, prop={'size': 8}, loc="upper left", ncol=3)
plt.title("Relationship between density and p-wave velocity")
plt.ylabel("$v_P$ velocity (m/s)")
plt.xlabel("Density $\\varrho$ (g/cm$^3$)")
plt.ylim(0.9*min(y), 1.1*max(y))
plt.xlim(1.7, 3.3)
plt.yticks(np.arange(round(0.9*min(y)/500,0)*500, round(1.1*max(y)/500,0)*500, 1000))
plt.xticks(np.arange(1.8, 3.4, 0.1))
plt.grid(True)
plt.rc('axes', axisbelow=True)

# %%
plt.figure(figsize=(10,8))
x = df["RHOB"]
y = df["VS"]
coordDrySand = [[],[]]
coordWetSand = [[],[]]
coordScree = [[],[]]
coordSoil = [[],[]]
coordSandstone = [[],[]]
coordLimestone = [[],[]]
coordDolomite = [[],[]]
coordShale = [[],[]]
coordHalite = [[],[]]
coordAnhydrite = [[],[]]
coordGranite = [[],[]]
coordBasalt = [[],[]]
for i in range(0, len(sequenceLog)):
	if sequenceLog[i] == "water":
		continue
	elif sequenceLog[i] == "dry sand":
		coordDrySand[0].append(x[i])
		coordDrySand[1].append(y[i])
	elif sequenceLog[i] == "wet sand":
		coordWetSand[0].append(x[i])
		coordWetSand[1].append(y[i])
	elif sequenceLog[i] == "scree":
		coordScree[0].append(x[i])
		coordScree[1].append(y[i])
	elif sequenceLog[i] == "soil":
		coordSoil[0].append(x[i])
		coordSoil[1].append(y[i])
	elif sequenceLog[i] == "sandstone":
		coordSandstone[0].append(x[i])
		coordSandstone[1].append(y[i])
	elif sequenceLog[i] == "limestone":
		coordLimestone[0].append(x[i])
		coordLimestone[1].append(y[i])
	elif sequenceLog[i] == "dolomite":
		coordDolomite[0].append(x[i])
		coordDolomite[1].append(y[i])
	elif sequenceLog[i] == "shale":
		coordShale[0].append(x[i])
		coordShale[1].append(y[i])
	elif sequenceLog[i] == "halite":
		coordHalite[0].append(x[i])
		coordHalite[1].append(y[i])
	elif sequenceLog[i] == "anhydrite":
		coordAnhydrite[0].append(x[i])
		coordAnhydrite[1].append(y[i])
	elif sequenceLog[i] == "granite":
		coordGranite[0].append(x[i])
		coordGranite[1].append(y[i])
	elif sequenceLog[i] == "basalt":
		coordBasalt[0].append(x[i])
		coordBasalt[1].append(y[i])
if len(coordDrySand[0]) > 0:
	plt.scatter(coordDrySand[0], coordDrySand[1], c="gold", label="dry sand", alpha=0.8)
else:
	pass
if len(coordSoil[0]) > 0:
	plt.scatter(coordSoil[0], coordSoil[1], c="saddlebrown", label="soil", alpha=0.8)
else:
	pass
plt.scatter(coordWetSand[0], coordWetSand[1], c="palegoldenrod", label="wet sand", alpha=0.8)
if len(coordSandstone[0]) > 0:
	plt.scatter(coordSandstone[0], coordSandstone[1], c="peru", label="sandstone", alpha=0.8)
if len(coordLimestone[0]) > 0:
	plt.scatter(coordLimestone[0], coordLimestone[1], c="steelblue", label="limestone", alpha=0.8)
if len(coordDolomite[0]) > 0:
	plt.scatter(coordDolomite[0], coordDolomite[1], c="darkviolet", label="dolomite", alpha=0.8)
if len(coordShale[0]) > 0:
	plt.scatter(coordShale[0], coordShale[1], c="limegreen", label="shale", alpha=0.8)
if len(coordHalite[0]) > 0:
	plt.scatter(coordHalite[0], coordHalite[1], c="thistle", label="halite", alpha=0.8)
if len(coordAnhydrite[0]) > 0:
	plt.scatter(coordAnhydrite[0], coordAnhydrite[1], c="pink", label="anhydrite", alpha=0.8)
if len(coordGranite[0]) > 0:
	plt.scatter(coordGranite[0], coordGranite[1], c="coral", label="granite", alpha=0.8)
if len(coordBasalt[0]) > 0:
	plt.scatter(coordBasalt[0], coordBasalt[1], c="silver", label="basalt", alpha=0.8)
plt.legend(scatterpoints=1, prop={'size': 8}, loc="upper left", ncol=3)
plt.title("Relationship between density and p-wave velocity")
plt.ylabel("$v_S$ velocity (m/s)")
plt.xlabel("Density $\\varrho$ (g/cm$^3$)")
plt.ylim(0.9*min(y), 1.1*max(y))
plt.xlim(1.7, 3.3)
plt.yticks(np.arange(round(0.9*min(y)/500,0)*500, round(1.1*max(y)/500,0)*500, 1000))
plt.xticks(np.arange(1.8, 3.4, 0.1))
plt.grid(True)
plt.rc('axes', axisbelow=True)

# %%
plt.figure(figsize=(10,8))
x = df["RHOB"]
y = df["GR"]
coordDrySand = [[],[]]
coordWetSand = [[],[]]
coordScree = [[],[]]
coordSoil = [[],[]]
coordSandstone = [[],[]]
coordLimestone = [[],[]]
coordDolomite = [[],[]]
coordShale = [[],[]]
coordHalite = [[],[]]
coordAnhydrite = [[],[]]
coordGranite = [[],[]]
coordBasalt = [[],[]]
for i in range(0, len(sequenceLog)):
	if sequenceLog[i] == "water":
		continue
	elif sequenceLog[i] == "dry sand":
		coordDrySand[0].append(x[i])
		coordDrySand[1].append(y[i])
	elif sequenceLog[i] == "wet sand":
		coordWetSand[0].append(x[i])
		coordWetSand[1].append(y[i])
	elif sequenceLog[i] == "scree":
		coordScree[0].append(x[i])
		coordScree[1].append(y[i])
	elif sequenceLog[i] == "soil":
		coordSoil[0].append(x[i])
		coordSoil[1].append(y[i])
	elif sequenceLog[i] == "sandstone":
		coordSandstone[0].append(x[i])
		coordSandstone[1].append(y[i])
	elif sequenceLog[i] == "limestone":
		coordLimestone[0].append(x[i])
		coordLimestone[1].append(y[i])
	elif sequenceLog[i] == "dolomite":
		coordDolomite[0].append(x[i])
		coordDolomite[1].append(y[i])
	elif sequenceLog[i] == "shale":
		coordShale[0].append(x[i])
		coordShale[1].append(y[i])
	elif sequenceLog[i] == "halite":
		coordHalite[0].append(x[i])
		coordHalite[1].append(y[i])
	elif sequenceLog[i] == "anhydrite":
		coordAnhydrite[0].append(x[i])
		coordAnhydrite[1].append(y[i])
	elif sequenceLog[i] == "granite":
		coordGranite[0].append(x[i])
		coordGranite[1].append(y[i])
	elif sequenceLog[i] == "basalt":
		coordBasalt[0].append(x[i])
		coordBasalt[1].append(y[i])
if len(coordDrySand[0]) > 0:
	plt.scatter(coordDrySand[0], coordDrySand[1], c="gold", label="dry sand", alpha=0.8)
else:
	pass
if len(coordSoil[0]) > 0:
	plt.scatter(coordSoil[0], coordSoil[1], c="saddlebrown", label="soil", alpha=0.8)
else:
	pass
plt.scatter(coordWetSand[0], coordWetSand[1], c="palegoldenrod", label="wet sand", alpha=0.8)
if len(coordSandstone[0]) > 0:
	plt.scatter(coordSandstone[0], coordSandstone[1], c="peru", label="sandstone", alpha=0.8)
if len(coordLimestone[0]) > 0:
	plt.scatter(coordLimestone[0], coordLimestone[1], c="steelblue", label="limestone", alpha=0.8)
if len(coordDolomite[0]) > 0:
	plt.scatter(coordDolomite[0], coordDolomite[1], c="darkviolet", label="dolomite", alpha=0.8)
if len(coordShale[0]) > 0:
	plt.scatter(coordShale[0], coordShale[1], c="limegreen", label="shale", alpha=0.8)
if len(coordHalite[0]) > 0:
	plt.scatter(coordHalite[0], coordHalite[1], c="thistle", label="halite", alpha=0.8)
if len(coordAnhydrite[0]) > 0:
	plt.scatter(coordAnhydrite[0], coordAnhydrite[1], c="pink", label="anhydrite", alpha=0.8)
if len(coordGranite[0]) > 0:
	plt.scatter(coordGranite[0], coordGranite[1], c="coral", label="granite", alpha=0.8)
if len(coordBasalt[0]) > 0:
	plt.scatter(coordBasalt[0], coordBasalt[1], c="silver", label="basalt", alpha=0.8)
plt.legend(scatterpoints=1, prop={'size': 8}, loc="best", ncol=3)
plt.ylabel("GR (API)")
plt.xlabel("Density $\\varrho$ (g/cm$^3$)")
plt.ylim(0.9*min(y), 1.1*max(y))
plt.xlim(1.7, 3.3)
plt.yticks(np.arange(round(0.9*min(y)/50,0)*50, round(1.1*max(y)/50,0)*50+50, 25))
plt.xticks(np.arange(1.8, 3.4, 0.1))
plt.grid(True)
plt.rc('axes', axisbelow=True)

# %%
plt.figure(figsize=(10,8))
x = df["PHIN"]
y = df["RHOB"]
coordDrySand = [[],[]]
coordWetSand = [[],[]]
coordScree = [[],[]]
coordSoil = [[],[]]
coordSandstone = [[],[]]
coordLimestone = [[],[]]
coordDolomite = [[],[]]
coordShale = [[],[]]
coordHalite = [[],[]]
coordAnhydrite = [[],[]]
coordGranite = [[],[]]
coordBasalt = [[],[]]
for i in range(0, len(sequenceLog)):
	if sequenceLog[i] == "water":
		continue
	elif sequenceLog[i] == "dry sand":
		coordDrySand[0].append(x[i])
		coordDrySand[1].append(y[i])
	elif sequenceLog[i] == "wet sand":
		coordWetSand[0].append(x[i])
		coordWetSand[1].append(y[i])
	elif sequenceLog[i] == "scree":
		coordScree[0].append(x[i])
		coordScree[1].append(y[i])
	elif sequenceLog[i] == "soil":
		coordSoil[0].append(x[i])
		coordSoil[1].append(y[i])
	elif sequenceLog[i] == "sandstone":
		coordSandstone[0].append(x[i])
		coordSandstone[1].append(y[i])
	elif sequenceLog[i] == "limestone":
		coordLimestone[0].append(x[i])
		coordLimestone[1].append(y[i])
	elif sequenceLog[i] == "dolomite":
		coordDolomite[0].append(x[i])
		coordDolomite[1].append(y[i])
	elif sequenceLog[i] == "shale":
		coordShale[0].append(x[i])
		coordShale[1].append(y[i])
	elif sequenceLog[i] == "halite":
		coordHalite[0].append(x[i])
		coordHalite[1].append(y[i])
	elif sequenceLog[i] == "anhydrite":
		coordAnhydrite[0].append(x[i])
		coordAnhydrite[1].append(y[i])
	elif sequenceLog[i] == "granite":
		coordGranite[0].append(x[i])
		coordGranite[1].append(y[i])
	elif sequenceLog[i] == "basalt":
		coordBasalt[0].append(x[i])
		coordBasalt[1].append(y[i])
if len(coordDrySand[0]) > 0:
	plt.scatter(coordDrySand[0], coordDrySand[1], c="gold", label="dry sand", alpha=0.8)
else:
	pass
if len(coordSoil[0]) > 0:
	plt.scatter(coordSoil[0], coordSoil[1], c="saddlebrown", label="soil", alpha=0.8)
else:
	pass
plt.scatter(coordWetSand[0], coordWetSand[1], c="palegoldenrod", label="wet sand", alpha=0.8)
if len(coordSandstone[0]) > 0:
	plt.scatter(coordSandstone[0], coordSandstone[1], c="peru", label="sandstone", alpha=0.8)
if len(coordLimestone[0]) > 0:
	plt.scatter(coordLimestone[0], coordLimestone[1], c="steelblue", label="limestone", alpha=0.8)
if len(coordDolomite[0]) > 0:
	plt.scatter(coordDolomite[0], coordDolomite[1], c="darkviolet", label="dolomite", alpha=0.8)
if len(coordShale[0]) > 0:
	plt.scatter(coordShale[0], coordShale[1], c="limegreen", label="shale", alpha=0.8)
if len(coordHalite[0]) > 0:
	plt.scatter(coordHalite[0], coordHalite[1], c="thistle", label="halite", alpha=0.8)
if len(coordAnhydrite[0]) > 0:
	plt.scatter(coordAnhydrite[0], coordAnhydrite[1], c="pink", label="anhydrite", alpha=0.8)
if len(coordGranite[0]) > 0:
	plt.scatter(coordGranite[0], coordGranite[1], c="coral", label="granite", alpha=0.8)
if len(coordBasalt[0]) > 0:
	plt.scatter(coordBasalt[0], coordBasalt[1], c="silver", label="basalt", alpha=0.8)
plt.legend(scatterpoints=1, prop={'size': 8}, loc="best", ncol=3)
plt.xlabel("PHIN (%)")
plt.ylabel("Density $\\varrho$ (g/cm$^3$)")
plt.xlim(0, 40)
plt.ylim(1.7, 3.3)
plt.xticks(np.arange(0, 45, 5))
plt.yticks(np.arange(1.8, 3.4, 0.1))
plt.grid(True)
plt.rc('axes', axisbelow=True)

# %%
plt.figure(figsize=(10,8))
x = df["RHOB"]
y = df["POISSON"]
coordDrySand = [[],[]]
coordWetSand = [[],[]]
coordScree = [[],[]]
coordSoil = [[],[]]
coordSandstone = [[],[]]
coordLimestone = [[],[]]
coordDolomite = [[],[]]
coordShale = [[],[]]
coordHalite = [[],[]]
coordAnhydrite = [[],[]]
coordGranite = [[],[]]
coordBasalt = [[],[]]
for i in range(0, len(sequenceLog)):
	if sequenceLog[i] == "water":
		continue
	elif sequenceLog[i] == "dry sand":
		coordDrySand[0].append(x[i])
		coordDrySand[1].append(y[i])
	elif sequenceLog[i] == "wet sand":
		coordWetSand[0].append(x[i])
		coordWetSand[1].append(y[i])
	elif sequenceLog[i] == "scree":
		coordScree[0].append(x[i])
		coordScree[1].append(y[i])
	elif sequenceLog[i] == "soil":
		coordSoil[0].append(x[i])
		coordSoil[1].append(y[i])
	elif sequenceLog[i] == "sandstone":
		coordSandstone[0].append(x[i])
		coordSandstone[1].append(y[i])
	elif sequenceLog[i] == "limestone":
		coordLimestone[0].append(x[i])
		coordLimestone[1].append(y[i])
	elif sequenceLog[i] == "dolomite":
		coordDolomite[0].append(x[i])
		coordDolomite[1].append(y[i])
	elif sequenceLog[i] == "shale":
		coordShale[0].append(x[i])
		coordShale[1].append(y[i])
	elif sequenceLog[i] == "halite":
		coordHalite[0].append(x[i])
		coordHalite[1].append(y[i])
	elif sequenceLog[i] == "anhydrite":
		coordAnhydrite[0].append(x[i])
		coordAnhydrite[1].append(y[i])
	elif sequenceLog[i] == "granite":
		coordGranite[0].append(x[i])
		coordGranite[1].append(y[i])
	elif sequenceLog[i] == "basalt":
		coordBasalt[0].append(x[i])
		coordBasalt[1].append(y[i])
if len(coordDrySand[0]) > 0:
	plt.scatter(coordDrySand[0], coordDrySand[1], c="gold", label="dry sand", alpha=0.8)
else:
	pass
if len(coordSoil[0]) > 0:
	plt.scatter(coordSoil[0], coordSoil[1], c="saddlebrown", label="soil", alpha=0.8)
else:
	pass
plt.scatter(coordWetSand[0], coordWetSand[1], c="palegoldenrod", label="wet sand", alpha=0.8)
if len(coordSandstone[0]) > 0:
	plt.scatter(coordSandstone[0], coordSandstone[1], c="peru", label="sandstone", alpha=0.8)
if len(coordLimestone[0]) > 0:
	plt.scatter(coordLimestone[0], coordLimestone[1], c="steelblue", label="limestone", alpha=0.8)
if len(coordDolomite[0]) > 0:
	plt.scatter(coordDolomite[0], coordDolomite[1], c="darkviolet", label="dolomite", alpha=0.8)
if len(coordShale[0]) > 0:
	plt.scatter(coordShale[0], coordShale[1], c="limegreen", label="shale", alpha=0.8)
if len(coordHalite[0]) > 0:
	plt.scatter(coordHalite[0], coordHalite[1], c="thistle", label="halite", alpha=0.8)
if len(coordAnhydrite[0]) > 0:
	plt.scatter(coordAnhydrite[0], coordAnhydrite[1], c="pink", label="anhydrite", alpha=0.8)
if len(coordGranite[0]) > 0:
	plt.scatter(coordGranite[0], coordGranite[1], c="coral", label="granite", alpha=0.8)
if len(coordBasalt[0]) > 0:
	plt.scatter(coordBasalt[0], coordBasalt[1], c="silver", label="basalt", alpha=0.8)
plt.legend(scatterpoints=1, prop={'size': 8}, loc="best", ncol=3)
plt.ylabel("POISSON (1)")
plt.xlabel("Density $\\varrho$ (g/cm$^3$)")
plt.ylim(0.05, 0.5)
plt.xlim(1.7, 3.3)
plt.yticks(np.arange(0.05, 0.55, 0.05))
plt.xticks(np.arange(1.8, 3.4, 0.1))
plt.grid(True)
plt.rc('axes', axisbelow=True)

# %%
import ternary
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-109-22efc6486011> in <module>
# ----> 1 import ternary
#
# ModuleNotFoundError: No module named 'ternary'

# %%
data_Sandstone = []
RHOB_norm_Shale = []
for i in range(0, len(df["RHOB"])):
    if df["ROCK"][i] == "sandstone":
        data_Sandstone.append(((df["RHOB"][i]-df["RHOB"].min())/(df["RHOB"].max()-df["RHOB"].min()), 
                               (df["VP"][i]-df["VP"].min())/(df["VP"].max()-df["VP"].min()), 
                               (df["PHIN"][i]-df["PHIN"].min())/(df["PHIN"].max()-df["PHIN"].min())))
    elif df["ROCK"][i] == "shale":
        RHOB_norm_Shale.append((df["RHOB"][i]-df["RHOB"].min())/(df["RHOB"].max()-df["RHOB"].min()))
RHOB_normalized = (df["RHOB"]-df["RHOB"].min())/(df["RHOB"].max()-df["RHOB"].min())
VP_normalized = (df["VP"]-df["VP"].min())/(df["VP"].max()-df["VP"].min())
PHIN_normalized = (df["PHIN"]-df["PHIN"].min())/(df["PHIN"].max()-df["PHIN"].min())

# %%
d = {"RHOB": RHOB_normalized, "VP": VP_normalized, "PHIN": PHIN_normalized}
df_Ternary = pd.DataFrame(data=d)
df_Ternary.describe()
data = []
for i in range(0, len(df_Ternary["RHOB"])):
    data.append((df_Ternary["PHIN"][i]*100, df_Ternary["RHOB"][i]*100, df_Ternary["VP"][i]*100))
np.around(data_Sandstone,2)
print(min(data_Sandstone[0]), min(data_Sandstone[1]), min(data_Sandstone[2]))
print(max(data_Sandstone[0]), max(data_Sandstone[1]), max(data_Sandstone[2]))

# %%
df_Ternary.describe()

# %%
fig, tax = ternary.figure(scale=100)
fig.set_size_inches(10, 9)
tax.boundary(linewidth=1.0)
fontsize = 20

#tax.scatter(data_Sandstone)
tax.scatter(data, alpha=0.5)
tax.gridlines(multiple=10)
tax.get_axes().axis('off')
tax.top_corner_label("RHOB")
tax.left_corner_label("VP")
tax.right_corner_label("PHIN")
tax.ticks(axis='lbr', multiple=10, linewidth=1, offset=0.015)
tax.gridlines(color="black", multiple=10, linewidth=1)
tax.gridlines(color="gray", multiple=5, linewidth=1)
tax.clear_matplotlib_ticks()

# %%
lithologies = []
logGR = []
vP = []
vS = []
phiN = []
densitiesBottom = []
depthData = [0]
dataDepth = [[0], [0], [0]]
PE = []
AI = []
for i in range(0, len(df["ROCK"])):
    depthData.append(depthData[i] - df["THICKNESS"][i])
    logGR.append(df["GR"][i])
    vP.append(df["VP"][i])
    vS.append(df["VS"][i])
    densitiesBottom.append(df["RHOB"][i])
    phiN.append(df["PHIN"][i])
    dataDepth[0].append(depthData[i] - df["THICKNESS"][i])
    dataDepth[1].append(df["THICKNESS"][i])
    dataDepth[2].append(dataDepth[0][i] - dataDepth[1][i + 1] / 2)
    PE.append(df["PE"][i])
    AI.append(df["RHOB"][i]*df["VP"][i])
    if df["ROCK"][i] not in lithologies:
            lithologies.append(df["ROCK"][i])
            
del depthData[-1]
logGR.append(logGR[-1])
vP.append(vP[-1])
densitiesBottom.append(densitiesBottom[-1])
phiN.append(phiN[-1])
PE.append(PE[-1])

#data = seismics(df)
#dataImpedance = data.calculateImpedance()
#data = seismics(dataImpedance)
#dataReflection = data.calculateReflection()
#RC = dataReflection
#RC.append(dataReflection[-1])

sortedUnits = []
for i in range(0, len(lithologies)):
    sortedUnits.append([lithologies[i]])
for i in range(0, len(lithologies)):
    for j in range(0, len(df["ROCK"])):
        if df["ROCK"][j] in sortedUnits[i][0]:
            sortedUnits[i].append([-df["TOP"][j], -df["BOTTOM"][j]])
        else:
            continue

nUnits = []
usedLithologies = []
for i in range(0, len(sortedUnits)):
    if sortedUnits[i][0] == "water":
        sortedUnits[i].append("//")
        sortedUnits[i].append("royalblue")
        usedLithologies.append(["water", "", "royalblue"])
    elif sortedUnits[i][0] == "dry sand":
        sortedUnits[i].append("..")
        sortedUnits[i].append("gold")
        usedLithologies.append(["dry sand", "", "gold"])
    elif sortedUnits[i][0] == "wet sand":
        sortedUnits[i].append("..")
        sortedUnits[i].append("palegoldenrod")
        usedLithologies.append(["wet sand", "", "palegoldenrod"])
    elif sortedUnits[i][0] == "scree":
        sortedUnits[i].append("xx")
        sortedUnits[i].append("darkkhaki")
        usedLithologies.append(["scree", "", "darkkhaki"])
    elif sortedUnits[i][0] == "soil":
        sortedUnits[i].append("xx")
        sortedUnits[i].append("saddlebrown")
        usedLithologies.append(["soil", "", "saddlebrown"])
    elif sortedUnits[i][0] == "sandstone":
        sortedUnits[i].append("oo")
        sortedUnits[i].append("burlywood")
        usedLithologies.append(["sandstone", "", "burlywood"])
    elif sortedUnits[i][0] == "limestone":
        sortedUnits[i].append("++")
        sortedUnits[i].append("lightblue")
        usedLithologies.append(["limestone", "", "lightblue"])
    elif sortedUnits[i][0] == "dolomite":
        sortedUnits[i].append("++")
        sortedUnits[i].append("violet")
        usedLithologies.append(["dolomite", "", "violet"])
    elif sortedUnits[i][0] == "shale":
        sortedUnits[i].append("---")
        sortedUnits[i].append("palegreen")
        usedLithologies.append(["shale", "", "palegreen"])
    elif sortedUnits[i][0] == "halite":
        sortedUnits[i].append("**")
        sortedUnits[i].append("thistle")
        usedLithologies.append(["halite", "", "thistle"])
    elif sortedUnits[i][0] == "anhydrite":
        sortedUnits[i].append("**")
        sortedUnits[i].append("pink")
        usedLithologies.append(["anhydrite", "", "pink"])
    elif sortedUnits[i][0] == "granite":
        sortedUnits[i].append("**")
        sortedUnits[i].append("coral")
        usedLithologies.append(["granite", "", "coral"])
    elif sortedUnits[i][0] == "basalt":
        sortedUnits[i].append("++")
        sortedUnits[i].append("silver")
        usedLithologies.append(["basalt", "", "silver"])
    elif sortedUnits[i][0] == "ore":
        sortedUnits[i].append("++")
        sortedUnits[i].append("brown")
        usedLithologies.append(["ore", "", "brown"])
    nUnits.append(len(sortedUnits[i]) - 3)
    
usedPattern = []
usedColors = []
legendLith = []
for i in range(0, len(lithologies)):
    usedPattern.append(usedLithologies[i][1])
    usedColors.append(usedLithologies[i][2])
    legendLith.append(mpatches.Patch(facecolor=usedLithologies[i][2], hatch=usedLithologies[i][1], label=usedLithologies[i][0]))

# %%
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, sharey=True, figsize=(9, 12), dpi=75)
fig.subplots_adjust(wspace=0.25)
# 1
for i in range(0, len(nUnits)):
    for j in range(1, nUnits[i] + 1):
        ax1.hist(np.linspace(sortedUnits[i][j][0], sortedUnits[i][j][1]), bins=10, color=sortedUnits[i][-1], orientation="horizontal")
ax1.set_ylabel("Depth [m]")
ax1.set_xticklabels([])
ax1.set_ylim(min(depthData), 1.1 * max(depthData))
ax1.set_yticks(np.arange(0, -1.05 * sum(df["THICKNESS"]), -200))
ax1.grid(True)
ax1.grid(which="major", linewidth=1.0)
ax1.grid(which="minor", linewidth=0.5)
ax1.set_axisbelow(True)
ax1.legend(handles=legendLith, loc="lower center", bbox_to_anchor=(0.25, -0.125), shadow=True, ncol=2, prop={'size': 8})
# 2
ax2.plot(logGR, dataDepth[2], color="#00549F", linewidth=2)
ax2.set_xlabel("Gamma ray (API)")
ax2.set_xlim(0, max(logGR))
ax2.set_xticks(np.arange(0, max(logGR)+50, 100))
ax2.set_ylim(min(depthData), 1.1 * max(depthData))
ax2.set_yticks(np.arange(0, -1.05 * sum(df["THICKNESS"]), -200))
ax2.grid(b=True, which='major', color="black", linestyle="solid", linewidth=0.4, alpha=1)
ax2.grid(b=True, which='minor', color="black", linestyle="solid", linewidth=0.2, alpha=1)
ax2.minorticks_on()
plt.rc('axes', axisbelow=True)
# 3
vPedit = vP
del vPedit[-1]
vPedit.insert(0, vP[0])
vP_km = [i*0.001 for i in vP]
ax3.plot(vP_km, dataDepth[0], color="#00549F", linewidth=2)
ax3.set_xlabel("vP (km/s)")
ax3.set_xlim(0, 8.5)
ax3.set_xticks(np.arange(0, 8.5, 2.0))
ax3.set_ylim(min(depthData), 1.1 * max(depthData))
ax3.set_yticks(np.arange(0, -1.05 * sum(df["THICKNESS"]), -200))
ax3.grid(b=True, which='major', color="black", linestyle="solid", linewidth=0.4, alpha=1)
ax3.grid(b=True, which='minor', color="black", linestyle="solid", linewidth=0.2, alpha=1)
ax3.minorticks_on()
#
vSedit = vS
vSedit.insert(0, vS[0])
vS_km = [i*0.001 for i in vS]
ax3_2 = ax3.twiny()
ax3_2.plot(vS_km, dataDepth[0], color="#CC071E", linewidth=2)
ax3_2.set_xlabel("vS (km/s)")
ax3_2.set_xlim(0, 8.5)
ax3_2.set_xticks(np.arange(0, 8.5, 2.0))
ax3_2.minorticks_on()
plt.rc('axes', axisbelow=True)
plots = [mpatches.Patch(color="#00549F", label="VP"), mpatches.Patch(color="#CC071E", label="VS")]
ax3_2.legend(handles=plots, loc="lower right", bbox_to_anchor=(1, -0.125), prop={'size': 8})
# 4
plotRHOB = ax4.plot(densitiesBottom, dataDepth[2], color="#57AB27", linewidth=2, label="Densitiy log")
ax4.set_xlabel("Density [g/cm^3]")
ax4.set_xlim(1.70, 3.30)
ax4.set_xticks(np.around(np.linspace(1.70, 3.30, 4, endpoint=True), decimals=2))
ax4.grid(b=True, which='major', color="black", linestyle="solid", linewidth=0.4, alpha=1)
ax4.grid(b=True, which='minor', color="black", linestyle="solid", linewidth=0.2, alpha=1)
ax4.minorticks_on()
#
ax4_2 = ax4.twiny()
#phiN.append(phiN[-1])
plotPHIN = ax4_2.plot(phiN, dataDepth[2], color="#00549F", linewidth=2, linestyle="-", label="Neutron log")
ax4_2.set_xlabel("Neutron porosity [%]")
ax4_2.set_xlim(57, -27)
ax4_2.set_xticks(np.around(np.linspace(57, -27, 6, endpoint=True), decimals=0))
ax4_2.set_ylim(min(depthData), 1.1 * max(depthData))
ax4_2.set_yticks(np.arange(0, -1.05 * sum(df["THICKNESS"]), -200))
ax4_2.minorticks_on()
plt.rc('axes', axisbelow=True)
plots = [mpatches.Patch(color="#57AB27", label="RHOB"), mpatches.Patch(color="#00549F", label="PHIN")]
ax4_2.legend(handles=plots, loc="lower right", bbox_to_anchor=(1, -0.125), prop={'size': 8})
# 5
ax5.plot(PE, dataDepth[2], color="#006165", linewidth=2)
ax5.set_xlabel("PE (barns/electron)")
ax5.set_xscale('log')
ax5.set_xlim(min(PE), max(PE))
ax5.set_ylim(min(depthData), 1.1 * max(depthData))
ax5.set_yticks(np.arange(0, -1.05 * sum(df["THICKNESS"]), -200))
ax5.grid(b=True, which='major', color="black", linestyle="solid", linewidth=0.4, alpha=1)
ax5.grid(b=True, which='minor', color="black", linestyle="solid", linewidth=0.2, alpha=1)
ax5.minorticks_on()
plt.rc('axes', axisbelow=True)
#
plt.show()

# %%
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, sharey=True, figsize=(9, 12))
fig.subplots_adjust(wspace=0.25)
# 1
for i in range(0, len(nUnits)):
    for j in range(1, nUnits[i] + 1):
        ax1.hist(np.linspace(sortedUnits[i][j][0], sortedUnits[i][j][1]), bins=10, color=sortedUnits[i][-1], orientation="horizontal")
ax1.set_ylabel("Depth [m]")
ax1.set_xticklabels([])
ax1.set_ylim(min(depthData), 1.1 * max(depthData))
ax1.set_yticks(np.arange(0, -1.05 * sum(df["THICKNESS"]), -200))
ax1.grid(True)
ax1.grid(which="major", linewidth=1.0)
ax1.grid(which="minor", linewidth=0.5)
ax1.set_axisbelow(True)
ax1.legend(handles=legendLith, loc="lower center", bbox_to_anchor=(0.25, -0.125), shadow=True, ncol=2, prop={'size': 8})
# 2
plotRHOB = ax2.plot(densitiesBottom, dataDepth[0], color="#57AB27", linewidth=2, label="Densitiy log")
ax2.set_xlabel("Density [g/cm^3]")
ax2.set_xlim(1.70, 3.30)
ax2.set_xticks(np.around(np.linspace(1.70, 3.30, 4, endpoint=True), decimals=2))
ax2.grid(b=True, which='major', color="black", linestyle="solid", linewidth=0.4, alpha=1)
ax2.grid(b=True, which='minor', color="black", linestyle="solid", linewidth=0.2, alpha=1)
ax2.minorticks_on()
#
ax2_2 = ax2.twiny()
plotPHIN = ax2_2.plot(phiN, dataDepth[0], color="#00549F", linewidth=2, linestyle="-", label="Neutron log")
ax2_2.set_xlabel("Neutron porosity [%]")
ax2_2.set_xlim(57, -27)
ax2_2.set_xticks(np.around(np.linspace(57, -27, 6, endpoint=True), decimals=0))
ax2_2.set_ylim(min(depthData), 1.1 * max(depthData))
ax2_2.set_yticks(np.arange(0, -1.05 * sum(df["THICKNESS"]), -200))
ax2_2.minorticks_on()
plt.rc('axes', axisbelow=True)
plots = [mpatches.Patch(color="#57AB27", label="RHOB"), mpatches.Patch(color="#00549F", label="PHIN")]
ax2_2.legend(handles=plots, loc="lower right", bbox_to_anchor=(1, -0.125), prop={'size': 8})
# 3
vPedit = vP
vP_km = [i*0.001 for i in vP]
ax3.plot(vP_km, dataDepth[0], color="#00549F", linewidth=2)
ax3.set_xlabel("vP (km/s)")
ax3.set_xlim(0, 8)
ax3.set_xticks(np.arange(0, 8.5, 2.0))
ax3.set_ylim(min(depthData), 1.1 * max(depthData))
ax3.set_yticks(np.arange(0, -1.05 * sum(df["THICKNESS"]), -200))
ax3.grid(b=True, which='major', color="black", linestyle="solid", linewidth=0.4, alpha=1)
ax3.grid(b=True, which='minor', color="black", linestyle="solid", linewidth=0.2, alpha=1)
ax3.minorticks_on()
#
vSedit = vS
vS_km = [i*0.001 for i in vS]
ax3_2 = ax3.twiny()
ax3_2.plot(vS_km, dataDepth[0], color="#CC071E", linewidth=2)
ax3_2.set_xlabel("vS (km/s)")
ax3_2.set_xlim(0, 8)
ax3_2.set_xticks(np.arange(0, 8.5, 2.0))
ax3_2.minorticks_on()
plt.rc('axes', axisbelow=True)
plots = [mpatches.Patch(color="#00549F", label="VP"), mpatches.Patch(color="#CC071E", label="VS")]
ax3_2.legend(handles=plots, loc="lower right", bbox_to_anchor=(1, -0.125), prop={'size': 8})
# 4
AI = np.asarray(AI)/1000
ax4.plot(AI, dataDepth[2], color="#006165", linewidth=2)
ax4.set_xlabel("AI (kNs/m$3$)")
#ax4.set_xscale('log')
ax4.set_xlim(0, 25)
ax4.set_xticks(np.around(np.linspace(0, 30, 6, endpoint=True), decimals=0))
ax4.set_ylim(min(depthData), 1.1 * max(depthData))
ax4.set_yticks(np.arange(0, -1.05 * sum(df["THICKNESS"]), -200))
ax4.grid(b=True, which='major', color="black", linestyle="solid", linewidth=0.4, alpha=1)
ax4.grid(b=True, which='minor', color="black", linestyle="solid", linewidth=0.2, alpha=1)
ax4.minorticks_on()
plt.rc('axes', axisbelow=True)
# 5
ax5.plot(RC, dataDepth[2], color="#006165", linewidth=2)
ax5.set_xlabel("R (1)")
#ax5.set_xscale('symlog')
ax5.set_xlim(min(RC), max(RC))
ax5.set_ylim(min(depthData), 1.1 * max(depthData))
ax5.set_yticks(np.arange(0, -1.05 * sum(df["THICKNESS"]), -200))
ax5.grid(b=True, which='major', color="black", linestyle="solid", linewidth=0.4, alpha=1)
ax5.grid(b=True, which='minor', color="black", linestyle="solid", linewidth=0.2, alpha=1)
ax5.minorticks_on()
plt.rc('axes', axisbelow=True)
#
plt.show()
