# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = "../outputs/RockProperties_Anhydrite.csv"

# %%
df = pd.read_csv(data, sep=',', header=0, na_values='.')

# %%
df
# Out:
#          ROCK  THICKNESS     TOP  BOTTOM   RHOB       VP       VS   GR  PHIN  \
# 0   anhydrite        5.2  1043.0  1048.2  2.902  7176.89  4015.67  0.0   1.0
# 1   anhydrite        5.2  1048.2  1053.3  2.993  7016.74  3920.08  0.0   2.0
# 2   anhydrite        5.2  1053.3  1058.5  3.139  7137.15  3998.37  0.0   0.0
# 3   anhydrite        5.2  1058.5  1063.6  3.022  7143.12  3993.82  0.0   1.0
# 4   anhydrite        5.2  1063.6  1068.8  3.115  7116.97  3988.61  0.0   0.0
# 5   anhydrite        5.2  1068.8  1073.9  2.974  7089.01  3972.40  0.0   2.0
# 6   anhydrite        5.2  1073.9  1079.1  2.857  7009.52  3930.80  0.0   1.0
# 7   anhydrite        5.2  1079.1  1084.2  3.027  7175.68  4030.29  0.0   1.0
# 8   anhydrite        5.2  1084.2  1089.4  2.908  7205.97  4019.27  0.0   1.0
# 9   anhydrite        5.2  1089.4  1094.5  3.017  7146.55  4003.36  0.0   1.0
# 10  anhydrite        5.2  1094.5  1099.7  3.001  7298.61  4080.87  0.0   0.0
# ...

# %%
df.describe()
# Out:
#           THICKNESS          TOP       BOTTOM      RHOB           VP  \
# count  2.000000e+01    20.000000    20.000000  20.00000    20.000000
# mean   5.200000e+00  1091.950000  1097.100000   2.96970  7137.727000
# std    9.112518e-16    30.470046    30.465598   0.07550    81.082019
# min    5.200000e+00  1043.000000  1048.200000   2.85700  6990.240000
# 25%    5.200000e+00  1067.500000  1072.625000   2.91100  7081.327500
# 50%    5.200000e+00  1091.950000  1097.100000   2.97300  7144.835000
# 75%    5.200000e+00  1116.400000  1121.575000   3.01825  7192.167500
# max    5.200000e+00  1140.900000  1146.000000   3.13900  7298.610000
#
#                VS    GR       PHIN       POISSON        Anh  ...  \
# count    20.00000  20.0  20.000000  2.000000e+01  20.000000  ...
# mean   3995.95700   0.0   0.750000  2.700000e-01   0.926500  ...
# std      44.17703   0.0   0.786398  1.139065e-16   0.023458  ...
# min    3920.08000   0.0   0.000000  2.700000e-01   0.900000  ...
# ...

# %%
fig, axs = plt.subplots(3, 2, figsize=(15,20))
inputs = ["RHOB", "VP", "VS", "GR", "PHIN", "POISSON"]
for i in range(0, 3):
    for j in range(0, 2):
        for k in range(0, len(inputs)):
            axs[i,j].grid(color="#000000", linestyle='dashed')
            axs[i,j].set_ylabel("Frequency")
            axs[i,j].set_axisbelow(True)
axs[0,0].hist(df[inputs[0]], bins=25, color="#00549F", edgecolor="#000000")
axs[0,0].set_xlabel("RHOB (g/cm$^3$)")
axs[0,1].hist(df[inputs[3]], bins=25, color="#00549F", edgecolor="#000000")
axs[0,1].set_xlabel("GR (API)")
axs[1,0].hist(df[inputs[1]], bins=25, color="#00549F", edgecolor="#000000")
axs[1,0].set_xlabel("VP (m/s)")
axs[1,1].hist(df[inputs[2]], bins=25, color="#00549F", edgecolor="#000000")
axs[1,1].set_xlabel("VS (m/s)")
axs[2,0].hist(df[inputs[4]], bins=25, color="#00549F", edgecolor="#000000")
axs[2,0].set_xlabel("PHIN (%)")
axs[2,1].hist(df[inputs[5]], bins=25, color="#00549F", edgecolor="#000000")
axs[2,1].set_xlabel("POISSON (1)")
plt.grid(color="#000000", linestyle='dashed')
#

# %%
from pandas.plotting import scatter_matrix
import seaborn as sn

# %%
scatter_matrix(df[["RHOB", "GR", "PHIN", "VP", "VS", "POISSON"]], figsize=(12, 12), diagonal='hist');
# Out:
# C:\Users\MaximilianBeeskow\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:80: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# C:\Users\MaximilianBeeskow\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:80: UserWarning: Attempting to set identical left == right == 0.27 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# C:\Users\MaximilianBeeskow\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:81: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# C:\Users\MaximilianBeeskow\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:71: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
# ...

# %%
df.corr()
# Out:
#               THICKNESS           TOP        BOTTOM          RHOB  \
# THICKNESS  1.000000e+00  9.187271e-15  4.594306e-15  7.241755e-15
# TOP        9.187271e-15  1.000000e+00  9.999986e-01 -4.137942e-01
# BOTTOM     4.594306e-15  9.999986e-01  1.000000e+00 -4.140994e-01
# RHOB       7.241755e-15 -4.137942e-01 -4.140994e-01  1.000000e+00
# VP        -1.323463e-14  2.167107e-01  2.170363e-01  1.643774e-01
# VS        -3.168350e-15  2.286263e-01  2.289447e-01  1.767091e-01
# GR                  NaN           NaN           NaN           NaN
# PHIN       0.000000e+00 -3.673646e-01 -3.679674e-01 -2.805641e-01
# POISSON   -1.000000e+00 -9.187271e-15 -4.594306e-15 -7.241755e-15
# Anh        8.983280e-15  1.761733e-01  1.765304e-01 -1.509957e-01
# Hl         1.555912e-16  4.210508e-01  4.214899e-01 -6.782851e-01
# Cal        5.158209e-16 -2.498569e-01 -2.503440e-01  3.794256e-02
# Gn        -2.222915e-16 -5.619354e-01 -5.622713e-01  8.385091e-01
# ...

# %%
plt.figure(figsize=(10,10))
sn.heatmap(df.corr(), cmap="viridis", annot=True);
